# %%
import os
import time

import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
from gams import GamsWorkspace

# import seaborn as sns
import argparse

import sys

# %%
import os
from gams import *

# Assuming your Jupyter notebook and the GDX file are in the same directory 'crab'
# and your Jupyter server was started in the directory containing 'crab'

# Get the current working directory of the Jupyter Notebook
notebook_directory = %pwd

# The path to your GDX file relative to the notebook
gdx_file_path = os.path.join(notebook_directory, "SimulationResults_CGE.gdx")

print("Attempting to load GDX file from:", gdx_file_path)

# Create GAMS Workspace
WS = GamsWorkspace()

try:
    # Attempt to load the GDX file using the full path
    db = WS.add_database_from_gdx(gdx_file_path)
    print("Database loaded successfully.")
except Exception as e:
    print("Error loading GDX file:", e)
# Out:
# Attempting to load GDX file from: /Users/ataberna/Library/CloudStorage/OneDrive-DelftUniversityofTechnology/Documents/GitHub/CRAB_EU_EMS_coupling/crab/SimulationResults_CGE.gdx
# Database loaded successfully.

# %%
all_data = []
sectors = ['Agriculture', 'Industry_capital', 'Industry_rest', 'Construction',
           'Utilities', 'Logistics', 'Transport', 'Private_Services', 'Public_Services']
current_year = str(2020)
regions = ['NL11']

# Assuming 'db' is a list of symbol objects with a 'name' attribute and iterates to give records
for i, symbol in enumerate(db):
    filtered_data = []
    print(symbol.name)
    for record in symbol:
        region, sector, year = record.keys
        if region in regions and sector in sectors and year == current_year:
            print(region, sector, year, record.value)
            # Create a dictionary for each record and append to filtered_data
            filtered_data.append({'region': region, 'sector': sector, f'{symbol.name}': record.value})

    # If filtered_data is not empty, create a DataFrame and append it to all_data
    if filtered_data:
        all_data.append(pd.DataFrame(filtered_data))

# Combine all DataFrames into one DataFrame using reduce and merge
from functools import reduce

# Use functools.reduce to perform a cumulative merge operation
# Use outer join to ensure all data is kept and aligned without repetition
combined_data = reduce(lambda left, right: pd.merge(left, right, on=['region', 'sector'], how='outer'), all_data)

# Now combined_data should have all the data aligned without NaNs if the 'region' and 'sector' pairs match up
combined_data
# Out:
# K_XD_rate
# NL11 Agriculture 2020 1.8703413761967782
# NL11 Industry_capital 2020 0.6893987463816398
# NL11 Industry_rest 2020 2.910588991160614
# NL11 Construction 2020 1.274565540347857
# NL11 Utilities 2020 2.5160062137103125
# NL11 Logistics 2020 2.0479098643101348
# NL11 Transport 2020 0.8833702698597707
# NL11 Private_Services 2020 2.267256348929262
# NL11 Public_Services 2020 1.3275594027012954
# Consumption
# NL11 Agriculture 2020 385.52163969172216
# NL11 Industry_capital 2020 954.529595619173
# NL11 Industry_rest 2020 4190.907766655704
# NL11 Construction 2020 706.4378753569054
# NL11 Utilities 2020 474.2155427692498
# NL11 Logistics 2020 1666.3059307098972
# NL11 Transport 2020 447.00476280173825
# NL11 Private_Services 2020 3461.8944309933186
# NL11 Public_Services 2020 3296.173207189882
#   region            sector  K_XD_rate  Consumption
# 0   NL11       Agriculture   1.870341   385.521640
# 1   NL11  Industry_capital   0.689399   954.529596
# 2   NL11     Industry_rest   2.910589  4190.907767
# 3   NL11      Construction   1.274566   706.437875
# 4   NL11         Utilities   2.516006   474.215543
# 5   NL11         Logistics   2.047910  1666.305931
# 6   NL11         Transport   0.883370   447.004763
# 7   NL11  Private_Services   2.267256  3461.894431
# 8   NL11   Public_Services   1.327559  3296.173207

# %%
# in combined_data, if sector == 'Industry_capital', set 'Consumption' to 0
combined_data.loc[combined_data['sector'] == 'Industry_capital', 'Consumption'] = 0
# in combined_data. normalize the columns Consumption so that it sums to 1
combined_data['Consumption'] = combined_data['Consumption'] / combined_data['Consumption'].sum()

# %%
combined_data
# drop the columns 'region' 
combined_data = combined_data.drop(columns=['region'])
# save as cge_input.csv
combined_data.to_csv('cge_input.csv', index=False)

# %%
# read combined_data 
cge_input = pd.read_csv('cge_input.csv')

# %%
KL_RATIO  =  pd.read_csv("cge_input.csv")
KL_RATIO.set_index("sector", inplace=True)
KL_RATIO = KL_RATIO.to_dict()["K_XD_rate"]

# %% [markdown]
# ### Now let's work on the output

# %%
import pickle

# %%
def load_model(filename):
    with open(filename, 'rb') as f:
        model = pickle.load(f)
    return model

# %%
# load model  crab/saved_model_0.pkl
model = load_model('saved_model_0.pkl')

# %%
# get 
macro_variables = model.datacollector.get_model_vars_dataframe()
micro_variables = model.datacollector.get_agent_vars_dataframe()

# %%
micro_variables
# Out:
#         Step  AgentID              Type  Capital amount
# 0          1        1  Industry_capital            80.0
# 1          1        2  Industry_capital            76.0
# 2          1        3  Industry_capital            76.0
# 3          1        4  Industry_capital            72.0
# 4          1        5  Industry_capital            76.0
# ...      ...      ...               ...             ...
# 226015    20    11520         Transport             4.0
# 226016    20    11521         Utilities             9.0
# 226017    20    11522  Private_Services            11.0
# 226018    20    11523   Public_Services             7.0
# 226019    20    11524         Logistics            10.0
#
# [226020 rows x 4 columns]

# %%
sectors = ['Agriculture', 'Industry_capital', 'Industry_rest', 'Construction',
           'Utilities', 'Logistics', 'Transport', 'Private_Services', 'Public_Services']

pattern = '(' + '|'.join(sectors) + ')'  # create a pattern that matches any of the sectors

# use the str.extract method to extract the matching part of the string
micro_variables['Type'] = micro_variables['Type'].str.extract(pattern, expand=False)

# %%
macro_variables['Step'] = macro_variables.index + 1
micro_variables.reset_index(inplace=True)

# %%
micro_variables_grouped
# Out:
#      Step              Type  Capital amount
# 0       1       Agriculture       19.420000
# 1       1      Construction       19.500000
# 2       1  Industry_capital       77.626667
# 3       1     Industry_rest       29.213333
# 4       1         Logistics       19.500000
# ..    ...               ...             ...
# 175    20         Logistics       24.120000
# 176    20  Private_Services       35.350000
# 177    20   Public_Services       29.430000
# 178    20         Transport        8.053333
# 179    20         Utilities       11.260000
#
# [180 rows x 3 columns]

# %%
t = 2020
# get the Step where the year is t
first_step = macro_variables[macro_variables['Year'] == t]['Step'][0]
last_step = macro_variables[macro_variables['Year'] == t]['Step'].iloc[-1]

# %%
# The path to your GDX file relative to the notebook
gdx_file_path_out = os.path.join(notebook_directory, "SimulationResults_ABM.gdx")

print("Attempting to load GDX file from:", gdx_file_path_out)

# Create GAMS Workspace

try:
    # Attempt to load the GDX file using the full path
    db_out = WS.add_database_from_gdx(gdx_file_path_out)
    print("Database loaded successfully.")
except Exception as e:
    print("Error loading GDX file:", e)
# Out:
# Attempting to load GDX file from: /Users/ataberna/Library/CloudStorage/OneDrive-DelftUniversityofTechnology/Documents/GitHub/CRAB_EU_EMS_coupling/crab/SimulationResults_ABM.gdx
# Database loaded successfully.

# %%
for symbol in db_out:
    print(symbol.name)
    for record in symbol:
                     
        print(record.keys, record.value)
# Out:
# K_XD_rate
# ['NL11', 'Agriculture', '2020'] 1.8703413761967782
# ['NL11', 'Agriculture', '2021'] 1.8703484005540059
# ['NL11', 'Agriculture', '2022'] 1.8703553919707616
# ['NL11', 'Agriculture', '2023'] 1.87036235064999
# ['NL11', 'Agriculture', '2024'] 1.8703692768117592
# ['NL11', 'Agriculture', '2025'] 1.870376170675208
# ['NL11', 'Agriculture', '2026'] 1.8703830324585469
# ['NL11', 'Agriculture', '2027'] 1.8703898623790902
# ['NL11', 'Agriculture', '2028'] 1.870396660653253
# ['NL11', 'Agriculture', '2029'] 1.8704034274965384
# ['NL11', 'Agriculture', '2030'] 1.8704101631235823
# ['NL11', 'Agriculture', '2031'] 1.8704168677481137
# ['NL11', 'Agriculture', '2032'] 1.8704235415829897
# ['NL11', 'Agriculture', '2033'] 1.8704301848401945
# ['NL11', 'Agriculture', '2034'] 1.8704367977308487
# ['NL11', 'Agriculture', '2035'] 1.8704433804651892
# ['NL11', 'Agriculture', '2036'] 1.8704499332526248
# ['NL11', 'Agriculture', '2037'] 1.8704564563016826
# ['NL11', 'Agriculture', '2038'] 1.870462949820064
# ['NL11', 'Agriculture', '2039'] 1.870469414014616
# ['NL11', 'Agriculture', '2040'] 1.8704758490913471
# ['NL11', 'Agriculture', '2041'] 1.8704822552554388
# ['NL11', 'Agriculture', '2042'] 1.8704886327112502
# ['NL11', 'Agriculture', '2043'] 1.8704949816623093
# ['NL11', 'Agriculture', '2044'] 1.8705013023113335
# ['NL11', 'Agriculture', '2045'] 1.87050759486023
# ['NL11', 'Agriculture', '2046'] 1.8705138595100939
# ['NL11', 'Agriculture', '2047'] 1.8705200964612307
# ['NL11', 'Agriculture', '2048'] 1.8705263059131387
# ['NL11', 'Agriculture', '2049'] 1.8705324880645335
# ['NL11', 'Agriculture', '2050'] 1.8705386431133477
# ['NL11', 'Industry_capital', '2020'] 0.6893987463816398
# ['NL11', 'Industry_capital', '2021'] 0.689401209307579
# ['NL11', 'Industry_capital', '2022'] 0.6894036726958603
# ['NL11', 'Industry_capital', '2023'] 0.6894061365641344
# ['NL11', 'Industry_capital', '2024'] 0.6894086009320605
# ['NL11', 'Industry_capital', '2025'] 0.6894110658194167
# ['NL11', 'Industry_capital', '2026'] 0.6894135312461013
# ['NL11', 'Industry_capital', '2027'] 0.6894159972321228
# ['NL11', 'Industry_capital', '2028'] 0.6894184637976133
# ['NL11', 'Industry_capital', '2029'] 0.6894209309628166
# ['NL11', 'Industry_capital', '2030'] 0.6894233987480987
# ['NL11', 'Industry_capital', '2031'] 0.6894258671739384
# ['NL11', 'Industry_capital', '2032'] 0.6894283362609362
# ['NL11', 'Industry_capital', '2033'] 0.6894308060298071
# ['NL11', 'Industry_capital', '2034'] 0.6894332765013922
# ['NL11', 'Industry_capital', '2035'] 0.6894357476966377
# ['NL11', 'Industry_capital', '2036'] 0.6894382196366249
# ['NL11', 'Industry_capital', '2037'] 0.6894406923425395
# ['NL11', 'Industry_capital', '2038'] 0.6894431658356965
# ['NL11', 'Industry_capital', '2039'] 0.6894456401375278
# ['NL11', 'Industry_capital', '2040'] 0.6894481152695849
# ['NL11', 'Industry_capital', '2041'] 0.6894505912535402
# ['NL11', 'Industry_capital', '2042'] 0.689453068111185
# ['NL11', 'Industry_capital', '2043'] 0.6894555458644352
# ['NL11', 'Industry_capital', '2044'] 0.6894580245353253
# ['NL11', 'Industry_capital', '2045'] 0.689460504146014
# ['NL11', 'Industry_capital', '2046'] 0.6894629847187783
# ['NL11', 'Industry_capital', '2047'] 0.6894654662760225
# ['NL11', 'Industry_capital', '2048'] 0.689467948840267
# ['NL11', 'Industry_capital', '2049'] 0.6894704324341632
# ['NL11', 'Industry_capital', '2050'] 0.6894729170804776
# ['NL11', 'Industry_rest', '2020'] 2.910588991160614
# ['NL11', 'Industry_rest', '2021'] 2.910593777283966
# ['NL11', 'Industry_rest', '2022'] 2.910598570134998
# ['NL11', 'Industry_rest', '2023'] 2.910603369711714
# ['NL11', 'Industry_rest', '2024'] 2.9106081760248914
# ['NL11', 'Industry_rest', '2025'] 2.9106129890856813
# ['NL11', 'Industry_rest', '2026'] 2.910617808905633
# ['NL11', 'Industry_rest', '2027'] 2.910622635496691
# ['NL11', 'Industry_rest', '2028'] 2.9106274688712235
# ['NL11', 'Industry_rest', '2029'] 2.910632309041964
# ['NL11', 'Industry_rest', '2030'] 2.910637156022079
# ['NL11', 'Industry_rest', '2031'] 2.910642009825109
# ['NL11', 'Industry_rest', '2032'] 2.910646870465005
# ['NL11', 'Industry_rest', '2033'] 2.910651737956125
# ['NL11', 'Industry_rest', '2034'] 2.9106566123132094
# ['NL11', 'Industry_rest', '2035'] 2.910661493551405
# ['NL11', 'Industry_rest', '2036'] 2.9106663816862692
# ['NL11', 'Industry_rest', '2037'] 2.910671276733739
# ['NL11', 'Industry_rest', '2038'] 2.9106761787101565
# ['NL11', 'Industry_rest', '2039'] 2.9106810876322746
# ['NL11', 'Industry_rest', '2040'] 2.910686003517227
# ['NL11', 'Industry_rest', '2041'] 2.9106909263825647
# ['NL11', 'Industry_rest', '2042'] 2.9106958562462175
# ['NL11', 'Industry_rest', '2043'] 2.9107007931265247
# ['NL11', 'Industry_rest', '2044'] 2.9107057370422185
# ['NL11', 'Industry_rest', '2045'] 2.9107106880124505
# ['NL11', 'Industry_rest', '2046'] 2.910715646056744
# ['NL11', 'Industry_rest', '2047'] 2.910720611195025
# ['NL11', 'Industry_rest', '2048'] 2.9107255834476415
# ['NL11', 'Industry_rest', '2049'] 2.9107305628353073
# ['NL11', 'Industry_rest', '2050'] 2.9107355493791633
# ['NL11', 'Construction', '2020'] 1.274565540347857
# ['NL11', 'Construction', '2021'] 1.274568326619315
# ['NL11', 'Construction', '2022'] 1.274571116945299
# ['NL11', 'Construction', '2023'] 1.2745739113423618
# ['NL11', 'Construction', '2024'] 1.2745767098148282
# ['NL11', 'Construction', '2025'] 1.274579512367258
# ['NL11', 'Construction', '2026'] 1.2745823190044243
# ['NL11', 'Construction', '2027'] 1.2745851297313329
# ['NL11', 'Construction', '2028'] 1.2745879445531823
# ['NL11', 'Construction', '2029'] 1.2745907634754101
# ['NL11', 'Construction', '2030'] 1.2745935865036606
# ['NL11', 'Construction', '2031'] 1.2745964136437895
# ['NL11', 'Construction', '2032'] 1.274599244901887
# ['NL11', 'Construction', '2033'] 1.274602080284244
# ['NL11', 'Construction', '2034'] 1.2746049197973761
# ['NL11', 'Construction', '2035'] 1.2746077634480177
# ['NL11', 'Construction', '2036'] 1.2746106112431128
# ['NL11', 'Construction', '2037'] 1.2746134631898247
# ['NL11', 'Construction', '2038'] 1.2746163192955398
# ['NL11', 'Construction', '2039'] 1.2746191795678588
# ['NL11', 'Construction', '2040'] 1.2746220440145934
# ['NL11', 'Construction', '2041'] 1.2746249126437812
# ['NL11', 'Construction', '2042'] 1.2746277854636785
# ['NL11', 'Construction', '2043'] 1.2746306624827404
# ['NL11', 'Construction', '2044'] 1.2746335437096743
# ['NL11', 'Construction', '2045'] 1.2746364291533647
# ['NL11', 'Construction', '2046'] 1.2746393188229437
# ['NL11', 'Construction', '2047'] 1.274642212727746
# ['NL11', 'Construction', '2048'] 1.2746451108773336
# ['NL11', 'Construction', '2049'] 1.274648013281476
# ['NL11', 'Construction', '2050'] 1.2746509199501734
# ['NL11', 'Utilities', '2020'] 2.5160062137103125
# ['NL11', 'Utilities', '2021'] 2.5160134937124976
# ['NL11', 'Utilities', '2022'] 2.516020759042077
# ['NL11', 'Utilities', '2023'] 2.5160280098460395
# ['NL11', 'Utilities', '2024'] 2.5160352462779354
# ['NL11', 'Utilities', '2025'] 2.51604246849087
# ['NL11', 'Utilities', '2026'] 2.516049676637473
# ['NL11', 'Utilities', '2027'] 2.5160568708699342
# ['NL11', 'Utilities', '2028'] 2.5160640513399772
# ['NL11', 'Utilities', '2029'] 2.5160712181988982
# ['NL11', 'Utilities', '2030'] 2.516078371597546
# ['NL11', 'Utilities', '2031'] 2.5160855116863323
# ['NL11', 'Utilities', '2032'] 2.516092638615239
# ['NL11', 'Utilities', '2033'] 2.516099752533841
# ['NL11', 'Utilities', '2034'] 2.516106853591274
# ['NL11', 'Utilities', '2035'] 2.516113941936312
# ['NL11', 'Utilities', '2036'] 2.51612101771721
# ['NL11', 'Utilities', '2037'] 2.516128081081953
# ['NL11', 'Utilities', '2038'] 2.5161351321780474
# ['NL11', 'Utilities', '2039'] 2.516142171152647
# ['NL11', 'Utilities', '2040'] 2.5161491981525095
# ['NL11', 'Utilities', '2041'] 2.516156213324016
# ['NL11', 'Utilities', '2042'] 2.5161632168131693
# ['NL11', 'Utilities', '2043'] 2.5161702087656064
# ['NL11', 'Utilities', '2044'] 2.5161771893265956
# ['NL11', 'Utilities', '2045'] 2.5161841586410567
# ['NL11', 'Utilities', '2046'] 2.51619111685355
# ['NL11', 'Utilities', '2047'] 2.516198064108285
# ['NL11', 'Utilities', '2048'] 2.516205000549137
# ['NL12', 'Industry_capital', '2024'] 0.6031191290820638
# ['NL12', 'Industry_capital', '2025'] 0.6031209651026114
# ['NL12', 'Industry_capital', '2026'] 0.6031228011912803
# ['NL12', 'Industry_capital', '2027'] 0.6031246373569588
# ['NL12', 'Industry_capital', '2028'] 0.6031264736086442
# ['NL12', 'Industry_capital', '2029'] 0.6031283099554298
# ['NL12', 'Industry_capital', '2030'] 0.6031301464065176
# ['NL12', 'Industry_capital', '2031'] 0.6031319829712066
# ['NL12', 'Industry_capital', '2032'] 0.6031338196589036
# ['NL12', 'Industry_capital', '2033'] 0.603135656479115
# ['NL12', 'Industry_capital', '2034'] 0.603137493441451
# ['NL12', 'Industry_capital', '2035'] 0.6031393305556233
# ['NL12', 'Industry_capital', '2036'] 0.6031411678314456
# ['NL12', 'Industry_capital', '2037'] 0.6031430052788338
# ['NL12', 'Industry_capital', '2038'] 0.6031448429078077
# ['NL12', 'Industry_capital', '2039'] 0.6031466807284891
# ['NL12', 'Industry_capital', '2040'] 0.6031485187511003
# ['NL12', 'Industry_capital', '2041'] 0.6031503569859655
# ['NL12', 'Industry_capital', '2042'] 0.6031521954435161
# ['NL12', 'Industry_capital', '2043'] 0.6031540341342789
# ['NL12', 'Industry_capital', '2044'] 0.6031558730688873
# ['NL12', 'Industry_capital', '2045'] 0.6031577122580766
# ['NL12', 'Industry_capital', '2046'] 0.6031595517126769
# ['NL12', 'Industry_capital', '2047'] 0.6031613914436358
# ['NL12', 'Industry_capital', '2048'] 0.6031632314619866
# ['NL12', 'Industry_capital', '2049'] 0.6031650717788768
# ['NL12', 'Industry_capital', '2050'] 0.6031669124055483
# ['NL12', 'Industry_rest', '2020'] 2.539726775593385
# ['NL12', 'Industry_rest', '2021'] 2.5397319820038033
# ['NL12', 'Industry_rest', '2022'] 2.539737194136847
# ['NL12', 'Industry_rest', '2023'] 2.5397424119823824
# ['NL12', 'Industry_rest', '2024'] 2.539747635539343
# ['NL12', 'Industry_rest', '2025'] 2.539752864807085
# ['NL12', 'Industry_rest', '2026'] 2.5397580997853613
# ['NL12', 'Industry_rest', '2027'] 2.539763340474357
# ['NL12', 'Industry_rest', '2028'] 2.5397685868746707
# ['NL12', 'Industry_rest', '2029'] 2.5397738389873155
# ['NL12', 'Industry_rest', '2030'] 2.539779096813737
# ['NL12', 'Industry_rest', '2031'] 2.539784360355774
# ['NL12', 'Industry_rest', '2032'] 2.5397896296156945
# ['NL12', 'Industry_rest', '2033'] 2.539794904596191
# ['NL12', 'Industry_rest', '2034'] 2.5398001853003453
# ['NL12', 'Industry_rest', '2035'] 2.5398054717316834
# ['NL12', 'Industry_rest', '2036'] 2.5398107638941183
# ['NL12', 'Industry_rest', '2037'] 2.539816061791987
# ['NL12', 'Industry_rest', '2038'] 2.539821365430047
# ['NL12', 'Industry_rest', '2039'] 2.539826674813445
# ['NL12', 'Industry_rest', '2040'] 2.539831989947764
# ['NL12', 'Industry_rest', '2041'] 2.5398373108389887
# ['NL12', 'Industry_rest', '2042'] 2.539842637493511
# ['NL12', 'Industry_rest', '2043'] 2.5398479699181298
# ['NL12', 'Industry_rest', '2044'] 2.5398533081200556
# ['NL12', 'Industry_rest', '2045'] 2.5398586521069184
# ['NL12', 'Industry_rest', '2046'] 2.539864001886748
# ['NL12', 'Industry_rest', '2047'] 2.53986935746798
# ['NL12', 'Industry_rest', '2048'] 2.5398747188594673
# ['NL12', 'Industry_rest', '2049'] 2.539880086070451
# ['NL12', 'Industry_rest', '2050'] 2.539885459110602
# ['NL12', 'Construction', '2020'] 1.279709572439652
# ['NL12', 'Construction', '2021'] 1.279711958581684
# ['NL12', 'Construction', '2022'] 1.2797143488205092
# ['NL12', 'Construction', '2023'] 1.2797167431583611
# ['NL12', 'Construction', '2024'] 1.2797191415869644
# ['NL12', 'Construction', '2025'] 1.279721544098272
# ['NL12', 'Construction', '2026'] 1.2797239506844562
# ['NL12', 'Construction', '2027'] 1.2797263613379197
# ['NL12', 'Construction', '2028'] 1.279728776051268
# ['NL12', 'Construction', '2029'] 1.2797311948173475
# ['NL12', 'Construction', '2030'] 1.279733617629207
# ['NL12', 'Construction', '2031'] 1.279736044480124
# ['NL12', 'Construction', '2032'] 1.2797384753635894
# ['NL12', 'Construction', '2033'] 1.2797409102733197
# ['NL12', 'Construction', '2034'] 1.2797433492032402
# ['NL12', 'Construction', '2035'] 1.279745792147505
# ['NL12', 'Construction', '2036'] 1.2797482391004724
# ['NL12', 'Construction', '2037'] 1.2797506900567255
# ['NL12', 'Construction', '2038'] 1.2797531450110646
# ['NL12', 'Construction', '2039'] 1.2797556039585078
# ['NL12', 'Construction', '2040'] 1.27975806689428
# ['NL12', 'Construction', '2041'] 1.279760533813834
# ['NL12', 'Construction', '2042'] 1.279763004712831
# ['NL12', 'Construction', '2043'] 1.2797654795871451
# ['NL12', 'Construction', '2044'] 1.279767958432875
# ['NL12', 'Construction', '2045'] 1.2797704412463282
# ['NL12', 'Construction', '2046'] 1.2797729280240162
# ['NL12', 'Construction', '2047'] 1.2797754187626833
# ['NL12', 'Construction', '2048'] 1.27977791345928
# ['NL12', 'Construction', '2049'] 1.279780412110964
# ['NL12', 'Construction', '2050'] 1.2797829147151158
# ['NL12', 'Utilities', '2020'] 3.79040635019847
# ['NL12', 'Utilities', '2021'] 3.7904115433006234
# ['NL12', 'Utilities', '2022'] 3.790416727202017
# ['NL12', 'Utilities', '2023'] 3.7904219019987924
# ['NL12', 'Utilities', '2024'] 3.7904270677915535
# ['NL12', 'Utilities', '2025'] 3.7904322246805418
# ['NL12', 'Utilities', '2026'] 3.7904373727656395
# ['NL12', 'Utilities', '2027'] 3.7904425121463525
# ['NL12', 'Utilities', '2028'] 3.790447642921853
# ['NL12', 'Utilities', '2029'] 3.7904527651909383
# ['NL12', 'Utilities', '2030'] 3.790457879052086
# ['NL12', 'Utilities', '2031'] 3.7904629846034155
# ['NL12', 'Utilities', '2032'] 3.7904680819426986
# ['NL12', 'Utilities', '2033'] 3.790473171167397
# ['NL12', 'Utilities', '2034'] 3.7904782523746343
# ['NL12', 'Utilities', '2035'] 3.790483325661218
# ['NL12', 'Utilities', '2036'] 3.7904883911235867
# ['NL12', 'Utilities', '2037'] 3.7904934488579345
# ['NL12', 'Utilities', '2038'] 3.790498498960087
# ['NL12', 'Utilities', '2039'] 3.7905035415255917
# ['NL12', 'Utilities', '2040'] 3.790508576649694
# ['NL12', 'Utilities', '2041'] 3.790513604427328
# ['NL12', 'Utilities', '2042'] 3.7905186249531355
# ['NL12', 'Utilities', '2043'] 3.7905236383214724
# ['NL12', 'Utilities', '2044'] 3.790528644626397
# ['NL12', 'Utilities', '2045'] 3.7905336439617003
# ['NL12', 'Utilities', '2046'] 3.7905386364208753
# ['NL12', 'Utilities', '2047'] 3.790543622097163
# ['NL12', 'Utilities', '2048'] 3.7905486010835143
# ['NL12', 'Utilities', '2049'] 3.790553573472626
# ['NL12', 'Utilities', '2050'] 3.7905585393569208
# ['NL12', 'Logistics', '2020'] 2.0547819279904935
# ['NL12', 'Logistics', '2021'] 2.0547872340101536
# ['NL12', 'Logistics', '2022'] 2.05479254282239
# ['NL12', 'Logistics', '2023'] 2.054797854443209
# ['NL12', 'Logistics', '2024'] 2.054803168890332
# ['NL12', 'Logistics', '2025'] 2.0548084861818197
# ['NL12', 'Logistics', '2026'] 2.0548138063360617
# ['NL12', 'Logistics', '2027'] 2.0548191293717437
# ['NL12', 'Logistics', '2028'] 2.0548244553079047
# ['NL12', 'Logistics', '2029'] 2.0548297841638883
# ['NL12', 'Logistics', '2030'] 2.0548351159593636
# ['NL12', 'Logistics', '2031'] 2.0548404507143228
# ['NL12', 'Logistics', '2032'] 2.054845788449081
# ['NL12', 'Logistics', '2033'] 2.054851129184266
# ['NL12', 'Logistics', '2034'] 2.0548564729408425
# ['NL12', 'Logistics', '2035'] 2.0548618197400854
# ['NL12', 'Logistics', '2036'] 2.0548671696035963
# ['NL12', 'Logistics', '2037'] 2.0548725225532887
# ['NL12', 'Logistics', '2038'] 2.0548778786114132
# ['NL12', 'Logistics', '2039'] 2.0548832378005315
# ['NL12', 'Logistics', '2040'] 2.054888600143528
# ['NL12', 'Logistics', '2041'] 2.054893965663609
# ['NL12', 'Logistics', '2042'] 2.0548993343843054
# ['NL12', 'Logistics', '2043'] 2.0549047063294625
# ['NL12', 'Logistics', '2044'] 2.0549100815232504
# ['NL12', 'Logistics', '2045'] 2.054915459990165
# ['NL12', 'Logistics', '2046'] 2.0549208417550173
# ['NL12', 'Logistics', '2047'] 2.0549262268429427
# ['NL12', 'Logistics', '2048'] 2.0549316152793997
# ['NL12', 'Logistics', '2049'] 2.0549370070901642
# ['NL12', 'Logistics', '2050'] 2.054942402301335
# ['NL12', 'Transport', '2020'] 1.045271988621585
# ['NL12', 'Transport', '2021'] 1.045275587649371
# ['NL12', 'Transport', '2022'] 1.0452791775193147
# ['NL12', 'Transport', '2023'] 1.0452827582880975
# ['NL12', 'Transport', '2024'] 1.0452863300164512
# ['NL12', 'Transport', '2025'] 1.0452898927650462
# ['NL12', 'Transport', '2026'] 1.0452934465945443
# ['NL12', 'Transport', '2027'] 1.0452969915655506
# ['NL12', 'Transport', '2028'] 1.045300527738652
# ['NL12', 'Transport', '2029'] 1.0453040551743935
# ['NL13', 'Utilities', '2025'] 3.676799834512766
# ['NL13', 'Utilities', '2026'] 3.6768048721396713
# ['NL13', 'Utilities', '2027'] 3.676809901919567
# ['NL13', 'Utilities', '2028'] 3.676814923933428
# ['NL13', 'Utilities', '2029'] 3.6768199382619944
# ['NL13', 'Utilities', '2030'] 3.6768249449857096
# ['NL13', 'Utilities', '2031'] 3.6768299441847745
# ['NL13', 'Utilities', '2032'] 3.6768349359391084
# ['NL13', 'Utilities', '2033'] 3.6768399203284057
# ['NL13', 'Utilities', '2034'] 3.676844897432077
# ['NL13', 'Utilities', '2035'] 3.6768498673293233
# ['NL13', 'Utilities', '2036'] 3.676854830099029
# ['NL13', 'Utilities', '2037'] 3.6768597858199175
# ['NL13', 'Utilities', '2038'] 3.676864734570427
# ['NL13', 'Utilities', '2039'] 3.676869676428784
# ['NL13', 'Utilities', '2040'] 3.67687461147297
# ['NL13', 'Utilities', '2041'] 3.6768795397807574
# ['NL13', 'Utilities', '2042'] 3.6768844614296783
# ['NL13', 'Utilities', '2043'] 3.6768893764970536
# ['NL13', 'Utilities', '2044'] 3.6768942850599853
# ['NL13', 'Utilities', '2045'] 3.6768991871953602
# ['NL13', 'Utilities', '2046'] 3.676904082979858
# ['NL13', 'Utilities', '2047'] 3.676908972489956
# ['NL13', 'Utilities', '2048'] 3.6769138558019296
# ['NL13', 'Utilities', '2049'] 3.6769187329918482
# ['NL13', 'Utilities', '2050'] 3.67692360413559
# ['NL13', 'Logistics', '2020'] 2.1979560906374482
# ['NL13', 'Logistics', '2021'] 2.1979609240490023
# ['NL13', 'Logistics', '2022'] 2.197965762746829
# ['NL13', 'Logistics', '2023'] 2.1979706067126243
# ['NL13', 'Logistics', '2024'] 2.1979754559285687
# ['NL13', 'Logistics', '2025'] 2.197980310377322
# ['NL13', 'Logistics', '2026'] 2.197985170042006
# ['NL13', 'Logistics', '2027'] 2.197990034906217
# ['NL13', 'Logistics', '2028'] 2.19799490495402
# ['NL13', 'Logistics', '2029'] 2.1979997801699453
# ['NL13', 'Logistics', '2030'] 2.198004660538991
# ['NL13', 'Logistics', '2031'] 2.1980095460466234
# ['NL13', 'Logistics', '2032'] 2.1980144366787617
# ['NL13', 'Logistics', '2033'] 2.1980193324217967
# ['NL13', 'Logistics', '2034'] 2.1980242332625815
# ['NL13', 'Logistics', '2035'] 2.1980291391884204
# ['NL13', 'Logistics', '2036'] 2.1980340501870823
# ['NL13', 'Logistics', '2037'] 2.1980389662467936
# ['NL13', 'Logistics', '2038'] 2.198043887356231
# ['NL13', 'Logistics', '2039'] 2.198048813504536
# ['NL13', 'Logistics', '2040'] 2.1980537446812938
# ['NL13', 'Logistics', '2041'] 2.198058680876549
# ['NL13', 'Logistics', '2042'] 2.1980636220807916
# ['NL13', 'Logistics', '2043'] 2.1980685682849694
# ['NL13', 'Logistics', '2044'] 2.1980735194804675
# ['NL13', 'Logistics', '2045'] 2.198078475659136
# ['NL13', 'Logistics', '2046'] 2.198083436813256
# ['NL13', 'Logistics', '2047'] 2.198088402935564
# ['NL21', 'Agriculture', '2031'] 2.1099217624356763
# ['NL21', 'Agriculture', '2032'] 2.109927496785187
# ['NL21', 'Agriculture', '2033'] 2.109933202449517
# ['NL21', 'Agriculture', '2034'] 2.109938879623724
# ['NL21', 'Agriculture', '2035'] 2.109944528502041
# ['NL21', 'Agriculture', '2036'] 2.1099501492778976
# ['NL21', 'Agriculture', '2037'] 2.109955742143892
# ['NL21', 'Agriculture', '2038'] 2.109961307291828
# ['NL21', 'Agriculture', '2039'] 2.109966844912684
# ['NL21', 'Agriculture', '2040'] 2.1099723551966565
# ['NL21', 'Agriculture', '2041'] 2.1099778383331316
# ['NL21', 'Agriculture', '2042'] 2.109983294510729
# ['NL21', 'Agriculture', '2043'] 2.1099887239172603
# ['NL21', 'Agriculture', '2044'] 2.1099941267397586
# ['NL21', 'Agriculture', '2045'] 2.1099995031644965
# ['NL21', 'Agriculture', '2046'] 2.110004853376956
# ['NL21', 'Agriculture', '2047'] 2.110010177561868
# ['NL21', 'Agriculture', '2048'] 2.1100154759031926
# ['NL21', 'Agriculture', '2049'] 2.110020748584138
# ['NL21', 'Agriculture', '2050'] 2.1100259957871574
# ['NL21', 'Industry_capital', '2020'] 0.529799771465289
# ['NL21', 'Industry_capital', '2021'] 0.5298014254778407
# ['NL21', 'Industry_capital', '2022'] 0.5298030791165756
# ['NL21', 'Industry_capital', '2023'] 0.5298047323958704
# ['NL21', 'Industry_capital', '2024'] 0.5298063853317351
# ['NL21', 'Industry_capital', '2025'] 0.5298080379402537
# ['NL21', 'Industry_capital', '2026'] 0.5298096902375893
# ['NL21', 'Industry_capital', '2027'] 0.5298113422399711
# ['NL21', 'Industry_capital', '2028'] 0.5298129939637092
# ['NL21', 'Industry_capital', '2029'] 0.5298146454251815
# ['NL21', 'Industry_capital', '2030'] 0.5298162966408454
# ['NL21', 'Industry_capital', '2031'] 0.5298179476272256
# ['NL21', 'Industry_capital', '2032'] 0.5298195984009252
# ['NL21', 'Industry_capital', '2033'] 0.5298212489786199
# ['NL21', 'Industry_capital', '2034'] 0.5298228993770605
# ['NL21', 'Industry_capital', '2035'] 0.5298245496130692
# ['NL21', 'Industry_capital', '2036'] 0.5298261997035477
# ['NL21', 'Industry_capital', '2037'] 0.5298278496654703
# ['NL21', 'Industry_capital', '2038'] 0.5298294995158813
# ['NL21', 'Industry_capital', '2039'] 0.5298311492719082
# ['NL21', 'Industry_capital', '2040'] 0.529832798950748
# ['NL21', 'Industry_capital', '2041'] 0.5298344485696744
# ['NL21', 'Industry_capital', '2042'] 0.5298360981460383
# ['NL21', 'Industry_capital', '2043'] 0.5298377476972632
# ['NL21', 'Industry_capital', '2044'] 0.5298393972408526
# ['NL21', 'Industry_capital', '2045'] 0.529841046794381
# ['NL21', 'Industry_capital', '2046'] 0.5298426963755029
# ['NL21', 'Industry_capital', '2047'] 0.5298443460019469
# ['NL21', 'Industry_capital', '2048'] 0.529845995691522
# ['NL21', 'Industry_capital', '2049'] 0.5298476454621087
# ['NL21', 'Industry_capital', '2050'] 0.5298492953316692
# ['NL21', 'Industry_rest', '2020'] 2.54691629610031
# ['nonEU', 'Agriculture', '2023'] 1562090.506406235
# ['nonEU', 'Agriculture', '2024'] 1569902.837816606
# ['nonEU', 'Agriculture', '2025'] 1577754.2368537935
# ['nonEU', 'Agriculture', '2026'] 1585644.8988652746
# ['nonEU', 'Agriculture', '2027'] 1593575.0201752489
# ['nonEU', 'Agriculture', '2028'] 1601544.7980895126
# ['nonEU', 'Agriculture', '2029'] 1609554.4309003921
# ['nonEU', 'Agriculture', '2030'] 1617604.117891648
# ['nonEU', 'Agriculture', '2031'] 1625694.0593434426
# ['nonEU', 'Agriculture', '2032'] 1633824.4565373298
# ['nonEU', 'Agriculture', '2033'] 1641995.5117612537
# ['nonEU', 'Agriculture', '2034'] 1650207.4283145673
# ['nonEU', 'Agriculture', '2035'] 1658460.410513121
# ['nonEU', 'Agriculture', '2036'] 1666754.6636943044
# ['nonEU', 'Agriculture', '2037'] 1675090.3942221862
# ['nonEU', 'Agriculture', '2038'] 1683467.8094926276
# ['nonEU', 'Agriculture', '2039'] 1691887.1179384578
# ['nonEU', 'Agriculture', '2040'] 1700348.5290346304
# ['nonEU', 'Agriculture', '2041'] 1708852.253303471
# ['nonEU', 'Agriculture', '2042'] 1717398.50231987
# ['nonEU', 'Agriculture', '2043'] 1725987.488716584
# ['nonEU', 'Agriculture', '2044'] 1734619.4261895062
# ['nonEU', 'Agriculture', '2045'] 1743294.529502975
# ['nonEU', 'Agriculture', '2046'] 1752013.014495122
# ['nonEU', 'Agriculture', '2047'] 1760775.0980832533
# ['nonEU', 'Agriculture', '2048'] 1769580.9982692213
# ['nonEU', 'Agriculture', '2049'] 1778430.9341448627
# ['nonEU', 'Agriculture', '2050'] 1787325.1258974466
# ['nonEU', 'Industry_capital', '2020'] 2189452.6814181306
# ['nonEU', 'Industry_capital', '2021'] 2200402.7951998734
# ['nonEU', 'Industry_capital', '2022'] 2211407.667646785
# ['nonEU', 'Industry_capital', '2023'] 2222467.5725681134
# ['nonEU', 'Industry_capital', '2024'] 2233582.7851363
# ['nonEU', 'Industry_capital', '2025'] 2244753.5818996495
# ['nonEU', 'Industry_capital', '2026'] 2255980.2407891573
# ['nonEU', 'Industry_capital', '2027'] 2267263.041125442
# ['nonEU', 'Industry_capital', '2028'] 2278602.263625668
# ['nonEU', 'Industry_capital', '2029'] 2289998.1904105525
# ['nonEU', 'Industry_capital', '2030'] 2301451.1050113575
# ['nonEU', 'Industry_capital', '2031'] 2312961.292376948
# ['nonEU', 'Industry_capital', '2032'] 2324529.0388808986
# ['nonEU', 'Industry_capital', '2033'] 2336154.6323285922
# ['nonEU', 'Industry_capital', '2034'] 2347838.361964378
# ['nonEU', 'Industry_capital', '2035'] 2359580.518478795
# ['nonEU', 'Industry_capital', '2036'] 2371381.3940157527
# ['nonEU', 'Industry_capital', '2037'] 2383241.282179842
# ['nonEU', 'Industry_capital', '2038'] 2395160.478043606
# ['nonEU', 'Industry_capital', '2039'] 2407139.2781549115
# ['nonEU', 'Industry_capital', '2040'] 2419177.98054428
# ['nonEU', 'Industry_capital', '2041'] 2431276.8847323493
# ['nonEU', 'Industry_capital', '2042'] 2443436.2917372733
# ['nonEU', 'Industry_capital', '2043'] 2455656.5040822458
# ['nonEU', 'Industry_capital', '2044'] 2467937.8258030107
# ['nonEU', 'Industry_capital', '2045'] 2480280.5624554236
# ['nonEU', 'Industry_capital', '2046'] 2492685.021123036
# ['nonEU', 'Industry_capital', '2047'] 2505151.5104247727
# ['nonEU', 'Industry_capital', '2048'] 2517680.3405225673
# ['nonEU', 'Industry_capital', '2049'] 2530271.8231290868
# ['nonEU', 'Industry_capital', '2050'] 2542926.2715155045
# ['nonEU', 'Industry_rest', '2020'] 6696224.53635937
# ['nonEU', 'Industry_rest', '2021'] 6729714.985641249
# ['nonEU', 'Industry_rest', '2022'] 6763372.914360307
# ['nonEU', 'Industry_rest', '2023'] 6797199.159967204
# ['nonEU', 'Industry_rest', '2024'] 6831194.564083021
# ['nonEU', 'Industry_rest', '2025'] 6865359.972536917
# ['nonEU', 'Industry_rest', '2026'] 6899696.235387052
# ['nonEU', 'Industry_rest', '2027'] 6934204.206941767
# ['nonEU', 'Industry_rest', '2028'] 6968884.745780748
# ['nonEU', 'Industry_rest', '2029'] 7003738.714776496
# ['nonEU', 'Industry_rest', '2030'] 7038766.981115659
# ['nonEU', 'Industry_rest', '2031'] 7073970.416320673
# ['nonEU', 'Industry_rest', '2032'] 7109349.896271473
# ['nonEU', 'Industry_rest', '2033'] 7144906.301227179
# ['nonEU', 'Industry_rest', '2034'] 7180640.515848043
# ['nonEU', 'Industry_rest', '2035'] 7216553.429217481
# ['nonEU', 'Industry_rest', '2036'] 7252645.9348640945
# ['nonEU', 'Industry_rest', '2037'] 7288918.930783993
# ['nonEU', 'Industry_rest', '2038'] 7325373.319463047
# ['nonEU', 'Industry_rest', '2039'] 7362010.007899405
# ['nonEU', 'Industry_rest', '2040'] 7398829.907625965
# ['nonEU', 'Industry_rest', '2041'] 7435833.934733161
# ['nonEU', 'Industry_rest', '2042'] 7473023.009891576
# ['nonEU', 'Industry_rest', '2043'] 7510398.058375047
# ['nonEU', 'Industry_rest', '2044'] 7547960.01008349
# ['nonEU', 'Industry_rest', '2045'] 7585709.79956615
# ['nonEU', 'Industry_rest', '2046'] 7623648.36604475
# ['nonEU', 'Industry_rest', '2047'] 7661776.653436962
# ['nonEU', 'Industry_rest', '2048'] 7700095.610379783
# ['nonEU', 'Industry_rest', '2049'] 7738606.19025313
# ['nonEU', 'Industry_rest', '2050'] 7777309.351203661
# ['nonEU', 'Construction', '2020'] 87716.8267953459
# ['nonEU', 'Construction', '2021'] 88155.51409518797
# ['nonEU', 'Construction', '2022'] 88596.39518735821
# ['nonEU', 'Construction', '2023'] 89039.48104157709
# ['nonEU', 'Construction', '2024'] 89484.78268220882
# ['nonEU', 'Construction', '2025'] 89932.31118873988
# ['nonEU', 'Construction', '2026'] 90382.07769605372
# ['nonEU', 'Construction', '2027'] 90834.09339470722
# ['nonEU', 'Construction', '2028'] 91288.36953120932
# ['nonEU', 'Construction', '2029'] 91744.91740830093
# ['nonEU', 'Construction', '2030'] 92203.74838523527
# ['nonEU', 'Construction', '2031'] 92664.87387806112
# ['nonEU', 'Construction', '2032'] 93128.30535990674
# ['nonEU', 'Construction', '2033'] 93594.05436126493
# ['nonEU', 'Construction', '2034'] 94062.13247027929
# ['nonEU', 'Construction', '2035'] 94532.55133303431
# ['nonEU', 'Construction', '2036'] 95005.3226538423
# ['nonEU', 'Construction', '2037'] 95480.458195537
# ['nonEU', 'Construction', '2038'] 95957.96977976442
# ['nonEU', 'Construction', '2039'] 96437.86928727815
# ['nonEU', 'Construction', '2040'] 96920.16865823345
# ['nonEU', 'Construction', '2041'] 97404.87989248591
# ['nonEU', 'Construction', '2042'] 97892.0150498879
# ['nonEU', 'Construction', '2043'] 98381.58625059048
# ['nonEU', 'Construction', '2044'] 98873.60567534345
# ['nonEU', 'Construction', '2045'] 99368.08556579895
# ['nonEU', 'Construction', '2046'] 99865.03822481551
# ['nonEU', 'Construction', '2047'] 100364.4760167648
# ['nonEU', 'Construction', '2048'] 100866.41136783815
# ['nonEU', 'Construction', '2049'] 101370.85676635617
# ['nonEU', 'Construction', '2050'] 101877.82476307958
# ['nonEU', 'Utilities', '2020'] 589853.7842923271
# ['nonEU', 'Utilities', '2021'] 592804.3230821659
# ['nonEU', 'Utilities', '2022'] 595769.6111069897
# ['nonEU', 'Utilities', '2023'] 598749.7221345229
# ['nonEU', 'Utilities', '2024'] 601744.7302994492
# ['nonEU', 'Utilities', '2025'] 604754.7101070149
# ['nonEU', 'Utilities', '2026'] 607779.7364348692
# ['nonEU', 'Utilities', '2027'] 610819.8845349282
# ['nonEU', 'Utilities', '2028'] 613875.2300352374
# ['nonEU', 'Utilities', '2029'] 616945.8489418664
# ['nonEU', 'Utilities', '2030'] 620031.8176407845
# ['nonEU', 'Utilities', '2031'] 623133.2128997687
# ['nonEU', 'Utilities', '2032'] 626250.1118703131
# ['nonEU', 'Utilities', '2033'] 629382.5920895454
# ['nonEU', 'Utilities', '2034'] 632530.7314821522
# ['nonEU', 'Utilities', '2035'] 635694.6083623248
# ['nonEU', 'Utilities', '2036'] 638874.3014356961
# ['nonEU', 'Utilities', '2037'] 642069.8898013076
# ['nonEU', 'Utilities', '2038'] 645281.4529535712
# ['nonEU', 'Utilities', '2039'] 648509.0707842478
# ['nonEU', 'Utilities', '2040'] 651752.8235844325
# ['nonEU', 'Utilities', '2041'] 655012.7920465564
# ['nonEU', 'Utilities', '2042'] 658289.0572663828
# ['nonEU', 'Utilities', '2043'] 661581.7007450345
# ['nonEU', 'Utilities', '2044'] 664890.8043910167
# ['nonEU', 'Utilities', '2045'] 668216.4505222532
# ['nonEU', 'Utilities', '2046'] 671558.721868129
# ['nonEU', 'Utilities', '2047'] 674917.7015715607
# ['nonEU', 'Utilities', '2048'] 678293.4731910517
# ['nonEU', 'Utilities', '2049'] 681686.1207027716
# ['nonEU', 'Utilities', '2050'] 685095.7285026548
# ['nonEU', 'Logistics', '2020'] 5144685.964380856
# ['nonEU', 'Logistics', '2021'] 5170416.787794343
# ['nonEU', 'Logistics', '2022'] 5196276.287832804
# ['nonEU', 'Logistics', '2023'] 5222265.107927183
# ['nonEU', 'Logistics', '2024'] 5248383.894711568
# ['nonEU', 'Logistics', '2025'] 5274633.298053219
# ['nonEU', 'Logistics', '2026'] 5301013.971068678
# ['nonEU', 'Logistics', '2027'] 5327526.570139982
# ['nonEU', 'Logistics', '2028'] 5354171.754930994
# ['nonEU', 'Logistics', '2029'] 5380950.188403844
# ['nonEU', 'Logistics', '2030'] 5407862.536835336
# ['nonEU', 'Logistics', '2031'] 5434909.469833595
# ['nonEU', 'Logistics', '2032'] 5462091.6603547055
# ['nonEU', 'Logistics', '2033'] 5489409.78471944
# ['nonEU', 'Logistics', '2034'] 5516864.522630034
# ['nonEU', 'Logistics', '2035'] 5544456.557187202
# ['nonEU', 'Logistics', '2036'] 5572186.57490699
# ['nonEU', 'Logistics', '2037'] 5600055.265737968
# ['nonEU', 'Logistics', '2038'] 5628063.323078301
# ['nonEU', 'Logistics', '2039'] 5656211.443793083
# ['nonEU', 'Logistics', '2040'] 5684500.328231556
# ['nonEU', 'Logistics', '2041'] 5712930.680244661
# ['nonEU', 'Logistics', '2042'] 5741503.207202399
# ['nonEU', 'Logistics', '2043'] 5770218.620011544
# ['nonEU', 'Logistics', '2044'] 5799077.633133262
# ['nonEU', 'Logistics', '2045'] 5828080.964600902
# ['nonEU', 'Logistics', '2046'] 5857229.336037803
# ['nonEU', 'Logistics', '2047'] 5886523.472675358
# ['nonEU', 'Logistics', '2048'] 5915964.103370916
# ['nonEU', 'Logistics', '2049'] 5945551.960625979
# ['nonEU', 'Logistics', '2050'] 5975287.780604438
# ['nonEU', 'Transport', '2020'] 1110272.9812630857
# ['nonEU', 'Transport', '2021'] 1115825.783840352
# ['nonEU', 'Transport', '2022'] 1121406.3541560092
# ['nonEU', 'Transport', '2023'] 1127014.8310553378
# ['nonEU', 'Transport', '2024'] 1132651.3540749091
# ['nonEU', 'Transport', '2025'] 1138316.0634489688
# ['nonEU', 'Transport', '2026'] 1144009.1001129092
# ['nonEU', 'Transport', '2027'] 1149730.6057067774
# ['nonEU', 'Transport', '2028'] 1155480.7225787898
# ['nonEU', 'Transport', '2029'] 1161259.5937888827
# ['nonEU', 'Transport', '2030'] 1167067.3631122622
# ['nonEU', 'Transport', '2031'] 1172904.1750429801
# ['nonEU', 'Transport', '2032'] 1178770.1747975377
# ['nonEU', 'Transport', '2033'] 1184665.5083184852
# ['nonEU', 'Transport', '2034'] 1190590.3222780565
# ['nonEU', 'Transport', '2035'] 1196544.7640818201
# ['nonEU', 'Transport', '2036'] 1202528.9818723334
# ['nonEU', 'Transport', '2037'] 1208543.1245328437
# ['nonEU', 'Transport', '2038'] 1214587.3416909787
# ['nonEU', 'Transport', '2039'] 1220661.7837224724
# ['nonEU', 'Transport', '2040'] 1226766.6017549038
# ['nonEU', 'Transport', '2041'] 1232901.9476714605
# ['nonEU', 'Transport', '2042'] 1239067.9741147019
# ['nonEU', 'Transport', '2043'] 1245264.834490373
# ['nonEU', 'Transport', '2044'] 1251492.6829712107
# ['nonEU', 'Transport', '2045'] 1257751.674500776
# ['nonEU', 'Transport', '2046'] 1264041.964797309
# ['nonEU', 'Transport', '2047'] 1270363.710357608
# ['nonEU', 'Transport', '2048'] 1276717.068460917
# ['nonEU', 'Transport', '2049'] 1283102.1971728278
# ['nonEU', 'Transport', '2050'] 1289519.255349234
# ['nonEU', 'Private_Services', '2020'] 7890647.398896812
# ['nonEU', 'Private_Services', '2021'] 7930113.37822027
# ['nonEU', 'Private_Services', '2022'] 7969776.717925715
# ['nonEU', 'Private_Services', '2023'] 8009638.404853442
# ['nonEU', 'Private_Services', '2024'] 8049699.43075829
# ['nonEU', 'Private_Services', '2025'] 8089960.792353744
# ['nonEU', 'Private_Services', '2026'] 8130423.491336588
# ['nonEU', 'Private_Services', '2027'] 8171088.534411914
# ['nonEU', 'Private_Services', '2028'] 8211956.933318021
# ['nonEU', 'Private_Services', '2029'] 8253029.704851747
# ['nonEU', 'Private_Services', '2030'] 8294307.870893583
# ['nonEU', 'Private_Services', '2031'] 8335792.4584331885
# ['nonEU', 'Private_Services', '2032'] 8377484.499594966
# ['nonEU', 'Private_Services', '2033'] 8419385.031663598
# ['nonEU', 'Private_Services', '2034'] 8461495.097109942
# ['nonEU', 'Private_Services', '2035'] 8503815.743616974
# ['nonEU', 'Private_Services', '2036'] 8546348.024105733
# ['nonEU', 'Private_Services', '2037'] 8589092.996761618
# ['nonEU', 'Private_Services', '2038'] 8632051.725060634
# ['nonEU', 'Private_Services', '2039'] 8675225.277795905
# ['nonEU', 'Private_Services', '2040'] 8718614.729104185
# ['nonEU', 'Private_Services', '2041'] 8762221.158492614
# ['nonEU', 'Private_Services', '2042'] 8806045.650865518
# ['nonEU', 'Private_Services', '2043'] 8850089.296551462
# ['nonEU', 'Private_Services', '2044'] 8894353.191330351
# ['nonEU', 'Private_Services', '2045'] 8938838.436460542
# ['nonEU', 'Private_Services', '2046'] 8983546.138706455
# ['nonEU', 'Private_Services', '2047'] 9028477.410365922
# ['nonEU', 'Private_Services', '2048'] 9073633.369297959
# ['nonEU', 'Private_Services', '2049'] 9119015.13895046
# ['nonEU', 'Private_Services', '2050'] 9164623.848388242
# ['nonEU', 'Public_Services', '2020'] 7920740.548824587
# ['nonEU', 'Public_Services', '2021'] 7960345.36120552
# ['nonEU', 'Public_Services', '2022'] 8000148.206209329
# ['nonEU', 'Public_Services', '2023'] 8040150.074030585
# ['nonEU', 'Public_Services', '2024'] 8080351.959783756
# ['nonEU', 'Public_Services', '2025'] 8120754.863558857
# ['nonEU', 'Public_Services', '2026'] 8161359.79044613
# ['nonEU', 'Public_Services', '2027'] 8202167.750561184
# ['nonEU', 'Public_Services', '2028'] 8243179.759069937
# ['nonEU', 'Public_Services', '2029'] 8284396.836214076
# ['nonEU', 'Public_Services', '2030'] 8325820.0073362375
# ['nonEU', 'Public_Services', '2031'] 8367450.302905619
# ['nonEU', 'Public_Services', '2032'] 8409288.75854359
# ['nonEU', 'Public_Services', '2033'] 8451336.415049454
# ['nonEU', 'Public_Services', '2034'] 8493594.318426287
# ['nonEU', 'Public_Services', '2035'] 8536063.519907039
# ['nonEU', 'Public_Services', '2036'] 8578745.075980593
# ['nonEU', 'Public_Services', '2037'] 8621640.048418073
# ['nonEU', 'Public_Services', '2038'] 8664749.504299294
# ['nonEU', 'Public_Services', '2039'] 8708074.516039254
# ['nonEU', 'Public_Services', '2040'] 8751616.161414817
# ['nonEU', 'Public_Services', '2041'] 8795375.523591537
# ['nonEU', 'Public_Services', '2042'] 8839353.691150533
# ['nonEU', 'Public_Services', '2043'] 8883551.758115666
# ['nonEU', 'Public_Services', '2044'] 8927970.823980708
# ['nonEU', 'Public_Services', '2045'] 8972611.993736623
# ['nonEU', 'Public_Services', '2046'] 9017476.377899118
# ['nonEU', 'Public_Services', '2047'] 9062565.092536284
# ['nonEU', 'Public_Services', '2048'] 9107879.259296296
# ['nonEU', 'Public_Services', '2049'] 9153420.005435305
# ['nonEU', 'Public_Services', '2050'] 9199188.463845592

# %%
columns_out = ['Capital amount']
columns_names = ['K_firm_loss']
data_out = {}
n = 0
# groupby by micro_variables
micro_variables_grouped = micro_variables.groupby(['Step', 'Type'])[columns_out].mean().reset_index()
# for each column in micro_variables, get the % change between first step and last step , for each sector in the column 'Type'
for column in micro_variables_grouped.columns:
    if column in columns_out:
        data_out[columns_names[n]] = {}
        # get the % change between first step and last step, for each sector in the column 'Type'
        for sector in sectors:
            df_sector = micro_variables_grouped[(micro_variables_grouped['Type'] == sector)]
            first_value = df_sector[df_sector['Step'] == first_step][column].values[0]
            last_value = df_sector[df_sector['Step'] == last_step][column].values[0]
            # perc change
            perc_change = (last_value - first_value) / first_value * 100
            data_out[columns_names[n]][sector] = perc_change
        n += 1

# %%
for symbol in db_out:
    print(symbol.name)
    if symbol.name in data_out:
        data_to_add = data_out[symbol.name]
        for record in symbol:
            if record.keys[0] == 'NL11':
                if record.keys[2] == str(t):
                    # record_keys[1] is the sector, that is the same name in data_out
                    # I need to match them to update the value
                    sector = record.keys[1]
                    record.value = data_to_add[sector]
                    
                
                    print(record.keys, record.value)
# Out:
# I_additional_time_in
# K_firm_loss
# ['NL11', 'Agriculture', '2020'] -49.691040164778585
# ['NL11', 'Industry_capital', '2020'] -47.40638955685331
# ['NL11', 'Industry_rest', '2020'] -4.176175262437251
# ['NL11', 'Construction', '2020'] -49.69230769230769
# ['NL11', 'Utilities', '2020'] -42.60958205912335
# ['NL11', 'Logistics', '2020'] 23.692307692307697
# ['NL11', 'Transport', '2020'] -58.4308327598073
# ['NL11', 'Private_Services', '2020'] 80.54136874361596
# ['NL11', 'Public_Services', '2020'] 51.07802874743326

# %%
gdx_file_path_out = os.path.join(script_directory, output_filnename)
# save a sa gdx
db.export(gdx_file_path_out)
# Out:
# Attempting to load GDX file from: /Users/ataberna/Library/CloudStorage/OneDrive-DelftUniversityofTechnology/Documents/GitHub/CRAB_EU_EMS_coupling/crab/SimulationResults_ABM.gdx
# Database loaded successfully.

# %%
per_changes
# Out:
# {'Capital amount': -0.2241845621247363}

# %%
# need to load the GDX

# %%
macro_variables
# Out:
#     Flood  Year  HH consumption  Regional demand  Export demand  \
# 0   False  2020     6519.444235         6519.445            0.0
# 1   False  2020     7362.529235         7362.529            0.0
# 2   False  2020     8271.953235         8271.954            0.0
# 3   False  2020     8930.557591         8930.558            0.0
# 4   False  2020     8882.712377         9226.212            0.0
# 5   False  2020     9464.487695         9577.488            0.0
# 6   False  2020     9606.575075         9661.575            0.0
# 7   False  2020     9598.750702         9656.751            0.0
# 8   False  2020     9344.514123         9682.512            0.0
# 9   False  2020     9497.947489         9633.948            0.0
# 10  False  2020     9491.942979         9552.943            0.0
# 11  False  2020     9511.921025         9567.421            0.0
# 12  False  2020     9358.668901         9606.169            0.0
# 13  False  2020     9417.062753         9536.561            0.0
# 14  False  2020     9411.792670         9473.791            0.0
# 15  False  2020     9518.268008         9542.270            0.0
# 16  False  2020     9358.105929         9552.107            0.0
# 17  False  2020     9511.094113         9593.592            0.0
# 18  False  2020     9588.869324         9655.369            0.0
# 19  False  2020     9645.997830         9687.998            0.0
#
#     Unemployment rate  Min wage  Avg wage  Step
# 0                0.87     0.600  0.999572     1
# 1                0.69     0.600  1.037128     2
# 2                0.51     0.624  1.038769     3
# 3                0.35     0.624  1.038698     4
# 4                0.31     0.624  1.033876     5
# 5                0.19     0.618  1.033629     6
# 6                0.17     0.618  1.033472     7
# 7                0.17     0.618  1.033644     8
# 8                0.19     0.618  1.034409     9
# 9                0.19     0.618  1.034554    10
# 10               0.19     0.618  1.034103    11
# 11               0.19     0.618  1.034167    12
# 12               0.20     0.618  1.034863    13
# 13               0.21     0.618  1.035464    14
# 14               0.22     0.624  1.035289    15
# 15               0.20     0.624  1.035171    16
# 16               0.21     0.624  1.034669    17
# 17               0.19     0.618  1.034574    18
# 18               0.17     0.618  1.034300    19
# 19               0.16     0.618  1.034879    20

# %%
df = pd.DataFrame(filtered_data)

# %%
df
# Out:
#    region            sector  K_XD_rate  Consumption
# 0    NL11       Agriculture   1.870341          NaN
# 1    NL11  Industry_capital   0.689399          NaN
# 2    NL11     Industry_rest   2.910589          NaN
# 3    NL11      Construction   1.274566          NaN
# 4    NL11         Utilities   2.516006          NaN
# 5    NL11         Logistics   2.047910          NaN
# 6    NL11         Transport   0.883370          NaN
# 7    NL11  Private_Services   2.267256          NaN
# 8    NL11   Public_Services   1.327559          NaN
# 9    NL11       Agriculture        NaN   385.521640
# 10   NL11  Industry_capital        NaN   954.529596
# 11   NL11     Industry_rest        NaN  4190.907767
# 12   NL11      Construction        NaN   706.437875
# 13   NL11         Utilities        NaN   474.215543
# 14   NL11         Logistics        NaN  1666.305931
# 15   NL11         Transport        NaN   447.004763
# 16   NL11  Private_Services        NaN  3461.894431
# 17   NL11   Public_Services        NaN  3296.173207

# %%
interested_symbols = ['K_index', 'L_index']  # Add more symbols as needed
interested_years = [str(2015)]  # Add more years as needed
interested_regions = ['Netherlands']
# Assuming 'db' is your GAMS database object
filtered_data = []

# Iterate through all symbols in the database
for symbol in db:
    if symbol.name in interested_symbols:
        print(f"Symbol: {symbol.name}")
        for rec in symbol:
            if len(rec.keys) == 4:  # Assuming the order is region, sector, education, year
                region, sector, edu, year = rec.keys
            else:  # If 'education' is not present, assign NaN to edu
                region, sector, year = rec.keys
                edu = np.nan  # Use numpy's NaN for missing values
            
            # Now include the 'education' dimension in your filtering and data appending
            if region in interested_regions and year in interested_years:
                filtered_data.append({
                    'Region': region,
                    'Year': year,
                    'Sector': sector,
                    'Education': edu,  # Include 'education' regardless of its presence
                    'Value': rec.value
                })

# Convert the filtered data to a pandas DataFrame
df = pd.DataFrame(filtered_data)
# Out:
# Symbol: K_index
# Symbol: L_index

# %%
df
# Out:
#          Region  Year       Sector  Education         Value
# 0   Netherlands  2015      CPA_A01        NaN  2.220446e-14
# 1   Netherlands  2015      CPA_A02        NaN  2.220446e-14
# 2   Netherlands  2015  CPA_C10-C12        NaN  2.220446e-14
# 3   Netherlands  2015  CPA_C13-C15        NaN -1.110223e-14
# 4   Netherlands  2015      CPA_C17        NaN  2.220446e-14
# 5   Netherlands  2015      CPA_C18        NaN -1.110223e-14
# 6   Netherlands  2015      CPA_C21        NaN -2.220446e-14
# 7   Netherlands  2015      CPA_C26        NaN  2.220446e-14
# 8   Netherlands  2015      CPA_C30        NaN  2.220446e-14
# 9   Netherlands  2015      CPA_C33        NaN -1.110223e-14
# 10  Netherlands  2015      CPA_E36        NaN  2.220446e-14
# 11  Netherlands  2015  CPA_E37-E39        NaN -2.220446e-14
# 12  Netherlands  2015      CPA_G46        NaN  2.220446e-14
# 13  Netherlands  2015      CPA_H52        NaN  2.220446e-14
# 14  Netherlands  2015  CPA_J59_J60        NaN  2.220446e-14
# 15  Netherlands  2015      CPA_J61        NaN  2.220446e-14
# 16  Netherlands  2015  CPA_J62_J63        NaN -1.110223e-14
# 17  Netherlands  2015      CPA_K66        NaN  2.220446e-14
# 18  Netherlands  2015      CPA_M71        NaN  2.220446e-14
# 19  Netherlands  2015      CPA_M73        NaN -1.110223e-14
# 20  Netherlands  2015  CPA_M74_M75        NaN  2.220446e-14
# 21  Netherlands  2015  CPA_N80-N82        NaN  2.220446e-14
# 22  Netherlands  2015      CPA_Q86        NaN -1.110223e-14
# 23  Netherlands  2015      CPA_S96        NaN -2.220446e-14

# %%
# -- READ FILES -- #
HH_attributes = pd.read_csv("Input/HH_attributes.csv", index_col=0)
firm_flood_depths = pd.read_csv("Input/Firm_attributes.csv", index_col=0)
PMT_weights = pd.read_csv("Input/PMT_weights.csv", index_col=0)

# Extract parameters from GAMS database
interested_symbols = ['K_index', 'L_index']  # Add more symbols as needed
interested_years = [str(t)]  # Add more years as needed
interested_regions = ['Netherlands']
# Assuming 'db' is your GAMS database object
filtered_data = []

# Iterate through all symbols in the database
for symbol in db:
    if symbol.name in interested_symbols:
        print(f"Symbol: {symbol.name}")
        for rec in symbol:
            if len(rec.keys) == 4:  # Assuming the order is region, sector, education, year
                region, sector, edu, year = rec.keys
            else:  # If 'education' is not present, assign NaN to edu
                region, sector, year = rec.keys
                edu = np.nan  # Use numpy's NaN for missing values
            
            # Now include the 'education' dimension in your filtering and data appending
            if region in interested_regions and year in interested_years:
                filtered_data.append({
                    'Region': region,
                    'Year': year,
                    'Sector': sector,
                    'Education': edu,  # Include 'education' regardless of its presence
                    'Value': rec.value
                })

# Convert the filtered data to a pandas DataFrame
df = pd.DataFrame(filtered_data)
